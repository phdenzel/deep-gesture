# %% [markdown]
# ## Imports

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ## Holistic model setup

# %%
from holistic import HolisticMP
holistic = HolisticMP()

# %% [markdown]
# ## Camera feed setup

# %%
from camera import CVFeed
cvstream = CVFeed(device=0)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# ### Test holistic model on single capture

# %%
image = cvstream.single_capture()
holistic.detection(image)
holistic.draw(image)

# %%
plt.imshow(image)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Test camera feed loop

# %%
# cvstream.start(display_handler='nb')

# %%
cvstream.close()
